# %%
import random

list_1 = []
for i in range(5):
    user_value = input("What is your name? ")
    list_1.append(user_value)

winners = random.sample(list_1, 3)
for index, person in enumerate(winners, start=1):
    if index == 3:
        print(f"{person} is the THIRD winner! 🎉 Grand prize!")
    else:
        print(f"{person} is a winner!")
# Out:
# What is your name?  Joe
# What is your name?  Daniel
# What is your name?  Robert
# What is your name?  John
# What is your name?  Ryan
# Joe is a winner!
# John is a winner!
# Daniel is the THIRD winner! 🎉 Grand prize!
